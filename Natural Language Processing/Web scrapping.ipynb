# %%
from IPython.core.display import display, HTML
from bs4 import BeautifulSoup as bs

# %%
import requests

URL = "https://mmajunkie.usatoday.com/"
page = requests.get(URL)

print(page.text)
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]> <html lang="en-US" class="no-js ie-browser lt-ie9"> <![endif]-->
# <!--[if IE 9]> <html lang="en-US" class="no-js ie-browser ie9"> <![endif]-->
# <!--[if gt IE 9]><!--> <html lang="en-US" class="no-js"> <!--<![endif]-->
# <head>
#
#
#
# 		<!-- OneTrust Cookies Consent Notice start for usatoday.com -->
# <script src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript" charset="UTF-8" data-domain-script="5eaec3d6-175d-498f-a6a7-ec66eb9b9673" ></script>
# <script type="text/javascript">
# function OptanonWrapper() { }
# </script>
# <!-- OneTrust Cookies Consent Notice end for usatoday.com -->
# 	<script>(function(H){H.className=H.className.replace(/\bno-js\b/,'js')})(document.documentElement)</script>
#
# 	<meta charset="UTF-8">
# 	<meta http-equiv="X-UA-Compatible" content="IE=Edge">
# 	<meta name="viewport" content="width=device-width, initial-scale=1.0">
#
# 	<link rel="profile" href="http://gmpg.org/xfn/11">
# 	<link rel="pingback" href="https://mmajunkie.usatoday.com/xmlrpc.php">
#
#
# <meta name="description" content="UFC and MMA news, rumors, live blogs and videos" />
# <meta name="keywords" content="sponsored, trivia, 2017 mma road show, spinning back clique, bkfc, hablemos mma, mma rankings, cage warriors, one championship, axs tv fights, radio highlight, mma rumors, strikeforce, pfl, mma junkie radio, radio, blue corner, photo gallery, featured videos, bellator" /><meta name="google-site-verification" content="3pkiYHrgby0Ns8JdnVc1QQSGJaLp4BZG3fGupsQcrRg" />
#
# <title>MMA Junkie | UFC and MMA news, rumors, live blogs and videos</title>
# <script type="text/javascript">!(function(o,n,t){t=o.createElement(n),o=o.getElementsByTagName(n)[0],t.async=1,t.src="https://fuzzybasketball.com/v2tssuBg8KyUeBUBMP1pkLZZyr0rQ1J5sXdWgfiiCqEnsVNuKuJuDl2FeIdGWwL5i",o.parentNode.insertBefore(t,o)})(document,"script"),(function(o,n){o[n]=o[n]||function(){(o[n].q=o[n].q||[]).push(arguments)}})(window,"admiral");!(function(c,e,o,t,n){function r(o,t){(function n(){try{return 0<(localStorage.getItem("v4ac1eiZr0")||"").split(",")[4]}catch(o){}return!1})()&&(t=c[e].pubads())&&t.setTargeting("admiral-engaged","true")}(n=c[e]=c[e]||{}).cmd=n.cmd||[],typeof n.pubads===o?r():typeof n.cmd.unshift===o?n.cmd.unshift(r):n.cmd.push(r)})(window,"googletag","function");</script><meta name='robots' content='max-image-preview:large' />
# <link rel='dns-prefetch' href='//native.sharethrough.com' />
# <link rel='dns-prefetch' href='//mtrx.go.sonobi.com' />
# <link rel='dns-prefetch' href='//usatodaysports-d.openx.net' />
# <link rel='dns-prefetch' href='//micro.rubiconproject.com' />
# <link rel='dns-prefetch' href='//cdn.adsafeprotected.com' />
# <link rel='dns-prefetch' href='//www.usatoday.com' />
# <link rel='dns-prefetch' href='//cdn.confiant-integrations.net' />
# <link rel='dns-prefetch' href='//run.crtx.info' />
# <link rel='dns-prefetch' href='//www.googletagservices.com' />
# <link rel='dns-prefetch' href='//www.google-analytics.com' />
# <link rel='dns-prefetch' href='//stats.wp.com' />
# <link rel='dns-prefetch' href='//v0.wordpress.com' />
# <link rel="alternate" type="application/rss+xml" title="MMA Junkie &raquo; Feed" href="https://mmajunkie.usatoday.com/feed" />
# <link rel="alternate" type="application/rss+xml" title="MMA Junkie &raquo; Comments Feed" href="https://mmajunkie.usatoday.com/comments/feed" />
# <script type="text/javascript">
# window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/14.0.0\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/14.0.0\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/mmajunkie.usatoday.com\/wp-includes\/js\/wp-emoji-release.min.js?ver=6.2.2"}};
# /*! This file is auto-generated */
# !function(e,a,t){var n,r,o,i=a.createElement("canvas"),p=i.getContext&&i.getContext("2d");function s(e,t){p.clearRect(0,0,i.width,i.height),p.fillText(e,0,0);e=i.toDataURL();return p.clearRect(0,0,i.width,i.height),p.fillText(t,0,0),e===i.toDataURL()}function c(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(o=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},r=0;r<o.length;r++)t.supports[o[r]]=function(e){if(p&&p.fillText)switch(p.textBaseline="top",p.font="600 32px Arial",e){case"flag":return s("\ud83c\udff3\ufe0f\u200d\u26a7\ufe0f","\ud83c\udff3\ufe0f\u200b\u26a7\ufe0f")?!1:!s("\ud83c\uddfa\ud83c\uddf3","\ud83c\uddfa\u200b\ud83c\uddf3")&&!s("\ud83c\udff4\udb40\udc67\udb40\udc62\udb40\udc65\udb40\udc6e\udb40\udc67\udb40\udc7f","\ud83c\udff4\u200b\udb40\udc67\u200b\udb40\udc62\u200b\udb40\udc65\u200b\udb40\udc6e\u200b\udb40\udc67\u200b\udb40\udc7f");case"emoji":return!s("\ud83e\udef1\ud83c\udffb\u200d\ud83e\udef2\ud83c\udfff","\ud83e\udef1\ud83c\udffb\u200b\ud83e\udef2\ud83c\udfff")}return!1}(o[r]),t.supports.everything=t.supports.everything&&t.supports[o[r]],"flag"!==o[r]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[o[r]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(e=t.source||{}).concatemoji?c(e.concatemoji):e.wpemoji&&e.twemoji&&(c(e.twemoji),c(e.wpemoji)))}(window,document,window._wpemojiSettings);
# </script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 0.07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# 	<link rel='stylesheet' id='all-css-0' href='https://mmajunkie.usatoday.com/_static/??-' type='text/css' media='all' />
# <style id='wp-block-library-inline-css'>
# .has-text-align-justify{text-align:justify;}
# </style>
# <style id='elasticpress-facet-style-inline-css'>
# .widget_ep-facet input[type=search],.wp-block-elasticpress-facet input[type=search]{margin-bottom:1rem}.widget_ep-facet .searchable .inner,.wp-block-elasticpress-facet .searchable .inner{max-height:20em;overflow:scroll}.widget_ep-facet .term.hide,.wp-block-elasticpress-facet .term.hide{display:none}.widget_ep-facet .empty-term,.wp-block-elasticpress-facet .empty-term{opacity:.5;position:relative}.widget_ep-facet .empty-term:after,.wp-block-elasticpress-facet .empty-term:after{bottom:0;content:" ";display:block;left:0;position:absolute;right:0;top:0;width:100%;z-index:2}.widget_ep-facet .level-1,.wp-block-elasticpress-facet .level-1{padding-left:20px}.widget_ep-facet .level-2,.wp-block-elasticpress-facet .level-2{padding-left:40px}.widget_ep-facet .level-3,.wp-block-elasticpress-facet .level-3{padding-left:60px}.widget_ep-facet .level-4,.wp-block-elasticpress-facet .level-4{padding-left:5pc}.widget_ep-facet .level-5,.wp-block-elasticpress-facet .level-5{padding-left:75pt}.widget_ep-facet input[disabled],.wp-block-elasticpress-facet input[disabled]{cursor:pointer;opacity:1}.widget_ep-facet .term a,.wp-block-elasticpress-facet .term a{-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-ms-flexbox;display:flex;position:relative}.widget_ep-facet .term a:hover .ep-checkbox,.wp-block-elasticpress-facet .term a:hover .ep-checkbox{background-color:#ccc}.ep-checkbox{-webkit-box-align:center;-ms-flex-align:center;-ms-flex-negative:0;-webkit-box-pack:center;-ms-flex-pack:center;align-items:center;background-color:#eee;display:-webkit-box;display:-ms-flexbox;display:flex;flex-shrink:0;height:1em;justify-content:center;margin-right:.25em;width:1em}.ep-checkbox:after{border:solid #fff;border-width:0 .125em .125em 0;content:"";display:none;height:.5em;-webkit-transform:rotate(45deg);transform:rotate(45deg);width:.25em}.ep-checkbox.checked{background-color:#5e5e5e}.ep-checkbox.checked:after{display:block}
#
# </style>
# <link rel='stylesheet' id='all-css-2' href='https://mmajunkie.usatoday.com/_static/??/wp-content/mu-plugins/search/elasticpress-next/dist/css/related-posts-block-styles.min.css,/wp-includes/css/classic-themes.min.css?m=1687885540' type='text/css' media='all' />
# <style id='global-styles-inline-css'>
# body{--wp--preset--color--black: #000000;--wp--preset--color--cyan-bluish-gray: #abb8c3;--wp--preset--color--white: #ffffff;--wp--preset--color--pale-pink: #f78da7;--wp--preset--color--vivid-red: #cf2e2e;--wp--preset--color--luminous-vivid-orange: #ff6900;--wp--preset--color--luminous-vivid-amber: #fcb900;--wp--preset--color--light-green-cyan: #7bdcb5;--wp--preset--color--vivid-green-cyan: #00d084;--wp--preset--color--pale-cyan-blue: #8ed1fc;--wp--preset--color--vivid-cyan-blue: #0693e3;--wp--preset--color--vivid-purple: #9b51e0;--wp--preset--gradient--vivid-cyan-blue-to-vivid-purple: linear-gradient(135deg,rgba(6,147,227,1) 0%,rgb(155,81,224) 100%);--wp--preset--gradient--light-green-cyan-to-vivid-green-cyan: linear-gradient(135deg,rgb(122,220,180) 0%,rgb(0,208,130) 100%);--wp--preset--gradient--luminous-vivid-amber-to-luminous-vivid-orange: linear-gradient(135deg,rgba(252,185,0,1) 0%,rgba(255,105,0,1) 100%);--wp--preset--gradient--luminous-vivid-orange-to-vivid-red: linear-gradient(135deg,rgba(255,105,0,1) 0%,rgb(207,46,46) 100%);--wp--preset--gradient--very-light-gray-to-cyan-bluish-gray: linear-gradient(135deg,rgb(238,238,238) 0%,rgb(169,184,195) 100%);--wp--preset--gradient--cool-to-warm-spectrum: linear-gradient(135deg,rgb(74,234,220) 0%,rgb(151,120,209) 20%,rgb(207,42,186) 40%,rgb(238,44,130) 60%,rgb(251,105,98) 80%,rgb(254,248,76) 100%);--wp--preset--gradient--blush-light-purple: linear-gradient(135deg,rgb(255,206,236) 0%,rgb(152,150,240) 100%);--wp--preset--gradient--blush-bordeaux: linear-gradient(135deg,rgb(254,205,165) 0%,rgb(254,45,45) 50%,rgb(107,0,62) 100%);--wp--preset--gradient--luminous-dusk: linear-gradient(135deg,rgb(255,203,112) 0%,rgb(199,81,192) 50%,rgb(65,88,208) 100%);--wp--preset--gradient--pale-ocean: linear-gradient(135deg,rgb(255,245,203) 0%,rgb(182,227,212) 50%,rgb(51,167,181) 100%);--wp--preset--gradient--electric-grass: linear-gradient(135deg,rgb(202,248,128) 0%,rgb(113,206,126) 100%);--wp--preset--gradient--midnight: linear-gradient(135deg,rgb(2,3,129) 0%,rgb(40,116,252) 100%);--wp--preset--duotone--dark-grayscale: url('#wp-duotone-dark-grayscale');--wp--preset--duotone--grayscale: url('#wp-duotone-grayscale');--wp--preset--duotone--purple-yellow: url('#wp-duotone-purple-yellow');--wp--preset--duotone--blue-red: url('#wp-duotone-blue-red');--wp--preset--duotone--midnight: url('#wp-duotone-midnight');--wp--preset--duotone--magenta-yellow: url('#wp-duotone-magenta-yellow');--wp--preset--duotone--purple-green: url('#wp-duotone-purple-green');--wp--preset--duotone--blue-orange: url('#wp-duotone-blue-orange');--wp--preset--font-size--small: 13px;--wp--preset--font-size--medium: 20px;--wp--preset--font-size--large: 36px;--wp--preset--font-size--x-large: 42px;--wp--preset--spacing--20: 0.44rem;--wp--preset--spacing--30: 0.67rem;--wp--preset--spacing--40: 1rem;--wp--preset--spacing--50: 1.5rem;--wp--preset--spacing--60: 2.25rem;--wp--preset--spacing--70: 3.38rem;--wp--preset--spacing--80: 5.06rem;--wp--preset--shadow--natural: 6px 6px 9px rgba(0, 0, 0, 0.2);--wp--preset--shadow--deep: 12px 12px 50px rgba(0, 0, 0, 0.4);--wp--preset--shadow--sharp: 6px 6px 0px rgba(0, 0, 0, 0.2);--wp--preset--shadow--outlined: 6px 6px 0px -3px rgba(255, 255, 255, 1), 6px 6px rgba(0, 0, 0, 1);--wp--preset--shadow--crisp: 6px 6px 0px rgba(0, 0, 0, 1);}:where(.is-layout-flex){gap: 0.5em;}body .is-layout-flow > .alignleft{float: left;margin-inline-start: 0;margin-inline-end: 2em;}body .is-layout-flow > .alignright{float: right;margin-inline-start: 2em;margin-inline-end: 0;}body .is-layout-flow > .aligncenter{margin-left: auto !important;margin-right: auto !important;}body .is-layout-constrained > .alignleft{float: left;margin-inline-start: 0;margin-inline-end: 2em;}body .is-layout-constrained > .alignright{float: right;margin-inline-start: 2em;margin-inline-end: 0;}body .is-layout-constrained > .aligncenter{margin-left: auto !important;margin-right: auto !important;}body .is-layout-constrained > :where(:not(.alignleft):not(. ...
# .wp-block-navigation a:where(:not(.wp-element-button)){color: inherit;}
# :where(.wp-block-columns.is-layout-flex){gap: 2em;}
# .wp-block-pullquote{font-size: 1.5em;line-height: 1.6;}
# </style>
# <link rel='stylesheet' id='all-css-4' href='https://mmajunkie.usatoday.com/_static/??-' type='text/css' media='all' />
# <script>var googletag_cmd_push = function(o){ return googletag.cmd.push( o ); };</script><script id='mm-video-data-js-extra'>
# var mm_video_data = {"playerId":"01eqvpqbw4ymnv0rjh","endpointUrl":"https:\/\/vms-players.minutemediaservices.com","enableVideoUpload":"1"};
# var mm_plugin_data = {"pluginDir":"https:\/\/mmajunkie.usatoday.com\/wp-content\/plugins\/mm-video"};
# </script>
# <script type="text/javascript" src="https://mmajunkie.usatoday.com/_static/??-eJx9jv0KwjAMxF/IrsrG9B/xWUobtpQmnW26ube3+IFDUAgcXO5+nF4mhWxDcZC1r3ctkNaXNITc+LzT/0KKcEhGYBu2kQVYtIxAtVKykejMqoJZErAFTdGVUD81yEbwpvIYk9joYGPZhJN8I6dQBuQN820YeWyr8qtCpGZ0EPWT/DFq4ULnQ386dl3bt3t/B9HCaEo=" ></script><script id='amazon-adsystem-js-extra'>
# var amznAcctId = ["3090"];
# </script>
# <script id='amazon-adsystem-js-before'>
# !function(a9,a,p,s,t,A,g){if(a[a9])return;function q(c,r){a[a9]._Q.push([c,r])}a[a9]={init:function(){q("i",arguments)},fetchBids:function(){q("f",arguments)},setDisplayBids:function(){},_Q:[]};A=p.createElement(s);A.async=!0;A.src=t;g=p.getElementsByTagName(s)[0];g.parentNode.insertBefore(A,g)}("apstag",window,document,"script","//c.amazon-adsystem.com/aax2/apstag.js");window.bidSlots=window.bidSlots||[];window._mweb=0;apstag.init({pubID: amznAcctId[0], adServer: "googletag", deals: true});
# </script>
# <script src='https://mmajunkie.usatoday.com/wp-content/themes/usatoday-lawrence/js/bidder-manager.js?ver=6.2.2' id='amazon-adsystem-js'></script>
# <script src='https://mtrx.go.sonobi.com/morpheus.usatoday.1587.js?ver=6.2.2#defer' id='sonobi-adsystem-js'></script>
# <script src='https://usatodaysports-d.openx.net/w/1.0/jstag?nc=7103-USA_RON&#038;ver=6.2.2#defer' id='openx-adsystem-js'></script>
# <script async src='//micro.rubiconproject.com/prebid/dynamic/10968.js?ver=1.0#defer' id='lawrence_magnite_header_bidder_script-js'></script>
# <script src='https://cdn.adsafeprotected.com/iasPET.1.js?ver=1.0#defer' id='lawrence-ads-ias-js'></script>
# <script id='lawrence-ads-ias-js-after'>
# var iasDataHandler, __iasPET = __iasPET || {};
# 					__iasPET.queue = __iasPET.queue || [];
# 					__iasPETSlots = [];
# 					__iasPET.pubId = '922805';
# 					bidManager.addBidder( 'ias' );
#
# </script>
# <script id='lawrence-tealium-js-extra'>
# var gciDataLayer = {"event-type":"pageview","page-market-name":"smg","content-market-name":"mmajunkie","page-has-video":"no","page-has-gallery":"0","page-canonical-url":"https:\/\/mmajunkie.usatoday.com","content-ssts-section":"sports","content-ssts-subsection":"sports:mmajunkie","content-ssts-topic":"sports:mmajunkie","content-ssts-subtopic":"sports:mmajunkie","page-experience-type":"desktop","content-type":"homefront"};
# </script>
# <script id='lawrence-tealium-js-before'>
# 			window.gciAnalyticsUAID = "SMG-TEALIUM-MMAJUNKIE";
# 			gciDataLayer["page-full-url"]    = window.location.href;
# 			gciDataLayer["content-name"]     = window.location.pathname;
# 			gciDataLayer["page-referer"]     = document.referrer;
# 			gciDataLayer["page-has-gallery"] = Boolean(parseInt(gciDataLayer["page-has-gallery"], 10));
#
#
# 			var stateManager = {
# 				getActivePageInfo: function() {
# 					return {
# 						byline: gciDataLayer["content-byline"] || "",
# 						contentHeadline: gciDataLayer["content-headline"] || "",
# 						contentId: gciDataLayer["content-id"] || "",
# 						taxonomykeywords: gciDataLayer["content-keywords"] || "",
# 						contentType: gciDataLayer["content-type"] || "",
# 						cst: gciDataLayer["cst"] || "",
# 						pageHasVideo: (gciDataLayer["page-has-video"]) ? gciDataLayer["page-has-video"].toLowerCase() : "",
# 						ssts: gciDataLayer["content-ssts-subtopic"] || "",
# 					}
# 				}
# 			}
#
# </script>
# <script src='https://www.usatoday.com/dcjs/prod/main.js#defer' id='lawrence-tealium-js'></script>
# <script id='lawrence-tealium-js-after'>
# 			document.addEventListener("gciAnalyticsReady", function () {
# 				window.gciAnalytics.view(gciDataLayer);
# 			} );
#
# </script>
# <script async src='https://cdn.confiant-integrations.net/FvW3szAY_s729BZEa4_yfA6omyQ/gpt_and_prebid/config.js?ver=1.0.0' id='lawrence-confiant-js'></script>
# <script id='usatoday-gallery-js-extra'>
# var usatoday_gallery_ajax_object = {"publisherGA":"UA-166840762-5","sharethispubid":"fd7eb3e3-60ab-4eeb-9e7b-cb89e8ec8c83"};
# var _usmgOptions = {"ipdir":"r","gaid":"UA-166840762-5","dfpid":"7103","pid":"SMG_MMAJunkie","ads":[],"tlmurl":"http:\/\/tags.tiqcdn.com\/utag\/gci\/mmajunkie\/prod\/utag.js"};
# </script>
# <script type="text/javascript" src="https://mmajunkie.usatoday.com/_static/??-eJylzEEKgzAQheELNU6twbqRnmXQIUyIMTiTirc3Cy1dCi7f9+CHNZlhjkpRIYXsOApkQZ1H3MwJmNg4DIEWprJESAW8gBIGztPxbZWXB9zpZRlT8bVc5ltXr8vBH/DCR+kPSuYz9XXbva1t2ubpdyn/W/o=" ></script><script src='https://mmajunkie.usatoday.com/wp-content/plugins/usatoday-plugins/voltax-mmplayer/js/mmplayer.sdp.handler.js?ver=1.0' id='mmplayer_sdp_embed_handler-js'></script>
# <script id='mmplayer_sdp_embed_handler-js-after'>
# var __sdpA9JwTimeout = 2000,__sdpA9JwVast = "";
# </script>
# <script type="text/javascript" src="//run.crtx.info/track.min.js?ver=6.2.2#defer" id="ADRIZER_JS" data-domain="mmajunkie.com/"></script><script type="text/javascript" src="https://mmajunkie.usatoday.com/wp-content/themes/usatoday-lawrence/js/simple_reach.js?m=1687443630g" ></script><script src='//www.google-analytics.com/analytics.js?ver=6.2.2' id='lawrence-ga-create-js'></script>
# <script id='lawrence-ga-create-js-after'>
# ga('create', 'UA-166840762-5', {'name' : 'FishburneGATracker'});
# </script>
# <script id='mmajunkie-js-extra'>
# var mmajunkieAjaxOptions = [];
# </script>
# <script type="text/javascript" src="https://mmajunkie.usatoday.com/_static/??-eJylzdEKwjAMBdAfsquyMX0Rv6Wm0aVr09qmjP29Q3AM34ZvuRfOjZ6SgsiCLDr5+iQuuhYj0ZpZfQviBzEJqgI5eo9ZgYEBrS6JuHHloP9aca+KeW52jYVgXOWRULtN+OUyYMCN9mbKyPBBhWxeXy/3HuvpvlIhGOcF38L11F/OXdf27dG9AWJTgmY=" ></script><script src='https://api.playpickup.com/pickup-picker-v1.js?ver=6.2.2' id='picker_embed_script-js'></script>
# <link rel="https://api.w.org/" href="https://mmajunkie.usatoday.com/wp-json/" /><link rel="EditURI" type="application/rsd+xml" title="RSD" href="https://mmajunkie.usatoday.com/xmlrpc.php?rsd" />
# <link rel="wlwmanifest" type="application/wlwmanifest+xml" href="https://mmajunkie.usatoday.com/wp-includes/wlwmanifest.xml" />
# <meta name="generator" content="WordPress 6.2.2" />
# <link rel='shortlink' href='http://usat.ly/K356qW' />
# 	<style>img#wpstats{display:none}</style>
#
# <meta name="gdpr" content="false" />
#
# <script type="application/ld+json">
# 	{
# 		"@context": "http://schema.org",
# 		"@type": "WebPage",
# 		"mainEntityOfPage": {
# 			"@type": "WebPage",
# 			"@id": "https://mmajunkie.usatoday.com/lists/the-ultimate-fighter-31-mcgregor-vs-chandler-episode-5-recap-katona-vera"
# 		},
# 		"url": "https://mmajunkie.usatoday.com",
# 		"headline": "MMA Junkie",
# 	"publisher": {
# 		"@type": "Organization",
# 		"name": "MMA Junkie",
# 		"logo": {
# 			"@type": "ImageObject",
# 			"url": "https://mmajunkie.usatoday.com/wp-content/uploads/sites/91/2017/07/mmaj-header-logo.png"
# 		}
# 	}
# }
# </script>
# <meta name="sop-property" content="5874e80ec275500011a79cb4"><style type="text/css">
# </style>
# <link rel="canonical" href="https://mmajunkie.usatoday.com" />
# <meta name="apple-itunes-app" content="app-id=876544448, app-argument="><meta name="google-play-app" content="app-id=com.uts.mmaj">
# <!-- Include google_services.js -->
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
# 	var bottomAdMobileRendered = false,
# 		googletag = googletag || {},
# 		bidTimeout;
# 	googletag.cmd = googletag.cmd || [];
# 	bidManager.addBidder( 'magnite' );
# 	bidManager.timeout = 2500;
# 	bidManager.addBidder('a9');
# 	</script>
# <!-- helper function for targeting the url -->
# <script type='text/javascript'>
# (function(e,t){function i(){e.googletag=e.googletag||{};e.sdpTargeting=this.urlTargeting();e._sitePage=e.sdpTargeting.sp}var n,r;i.prototype.urlTargeting=function(){var t=e.location.pathname.replace(/\/$/,""),n=new RegExp("/([^/]*)","ig"),r=t.match(n),i=["/"],s="";if(r&&t!=="/"){var o="",u=r.length;if(u>0){for(var a=0;a<u;a++){o=r[a];i.push(o);for(var f=a+1;f<u;f++){o+=r[f];i.push(o)}if(a===0){i.splice(-1,1);s=o}}}i.push(s)}i=i.reverse();var l=e.location.toString().replace(/\=/ig,":").match(/\?(.+)$/),c=RegExp.$1.split("&"),h=e.location.toString().replace(/\/*(\?|\&|\x26)*(\w+=\w+)*$/,"");var p=h.replace(/http:\/\//,"").split("/");var d=p.length==1?"main":p[1].match(/^$|^index\.(php|htm|html)+$/i)?"main":"general";return{title:h,targetPaths:i.slice(0,9),fullPath:i[0],queryStr:c,domainName:e.location.hostname,sp:d}};n=new i})(window,document)
# </script>
# <script type='text/javascript'>
# if (typeof amznads !== "undefined") {
# 	var key = 'amznslots';
# 	var values = amznads.getTokens(); //comma separated
# }
# </script>
# <script type='text/javascript'>
# window.dfpTargetingObject = {"cst_subsection":[],"ssts_subsection":[],"cst_section":["sports","homepage"],"kw":[],"category":[],"cst_topic":[],"pageType":["home-front"],"referrer":"","build":"fishburne","isMobile":"0"};
# 	dfpTargetingObject.level2adunit = "SMG_MMAJunkie";
# 	window.usat_ad_tags = {};
# googletag_cmd_push(function() {
# 					window.usat_ad_tags['lawrence_dfp_desktop_skin'] = {"url":"","priority":10,"operator":"OR","toggle":1,"lazy_load":0,"refresh_enabled":1,"conditionals":[{"function":"is_home","arguments":[""]}],"url_vars":{"tag":"lawrence_dfp_desktop_skin","height":"1","width":"1","device_target":"desktop","tag_id":"div-gpt-ad-1383692344899-11","dfp_id":"7103","tag_name":"SMG_MMAJunkie\/skin\/sports\/mma\/main"}};
# 					window.lawrence_dfp_desktop_skin = googletag.defineSlot("/7103/SMG_MMAJunkie/skin/sports/mma/main", [1,1], "acm-ad-tag-lawrence_dfp_desktop_skin").addService(googletag.pubads().setTargeting('cst_subsection',[]).setTargeting('ssts_subsection',[]).setTargeting('cst_section',["sports","homepage"]).setTargeting('kw',[]).setTargeting('category',[]).setTargeting('cst_topic',[]).setTargeting('pageType',"home-front").setTargeting("referrer", "https://www.google.com/").setTargeting('build',"fishburne").setTargeting("title", sdpTargeting.title).setTargeting("targetPaths", sdpTargeting.targetPaths).setTargeting("fullPath", sdpTargeting.fullPath).setTargeting("queryStr", sdpTargeting.queryStr).setTargeting("domainName", sdpTargeting.domainName) ).setTargeting("position", ["skin"]);					window.usat_ad_tags['lawrence_dfp_desktop_interstitial'] = {"url":"","priority":10,"operator":"OR","toggle":1,"lazy_load":0,"refresh_enabled":1,"conditionals":[{"function":"is_home","arguments":[""]}],"url_vars":{"tag":"lawrence_dfp_desktop_interstitial","sizes":[{"width":"2","height":"1"}],"device_target":"desktop","tag_id":"div-gpt-ad-1383692344899-7","dfp_id":"7103","tag_name":"SMG_MMAJunkie\/interstitial\/sports\/mma\/main"}};
# 					window.lawrence_dfp_desktop_interstitial = googletag.defineSlot("/7103/SMG_MMAJunkie/interstitial/sports/mma/main", [[2,1]], "acm-ad-tag-lawrence_dfp_desktop_interstitial").addService(googletag.pubads().setTargeting('cst_subsection',[]).setTargeting('ssts_subsection',[]).setTargeting('cst_section',["sports","homepage"]).setTargeting('kw',[]).setTargeting('category',[]).setTargeting('cst_topic',[]).setTargeting('pageType',"home-front").setTargeting("referrer", "https://www.google.com/").setTargeting('build',"fishburne").setTargeting("title", sdpTargeting.title).setTargeting("targetPaths", sdpTargeting.targetPaths).setTargeting("fullPath", sdpTargeting.fullPath).setTargeting("queryStr", sdpTargeting.queryStr).setTargeting("domainName", sdpTargeting.domainName) ).setTargeting("position", ["interstitial"]);					window.usat_ad_tags['lawrence_dfp_desktop_sponsor_by_logo'] = {"url":"","priority":10,"operator":"OR","toggle":"1","lazy_load":0,"refresh_enabled":1,"conditionals":[{"function":"is_home","arguments":[""]}],"url_vars":{"tag":"lawrence_dfp_desktop_sponsor_by_logo","sizes":[{"width":"2","height":"2"}],"device_target":"","tag_id":"div-gpt-ad-1376086890206-13","dfp_id":"7103","tag_name":"SMG_MMAJunkie\/sponsor_logo\/sports\/mma\/general"}};
# 					window.lawrence_dfp_desktop_sponsor_by_logo = googletag.defineSlot("/7103/SMG_MMAJunkie/sponsor_logo/sports/mma/general", [[2,2]], "acm-ad-tag-lawrence_dfp_desktop_sponsor_by_logo").addService(googletag.pubads().setTargeting('cst_subsection',[]).setTargeting('ssts_subsection',[]).setTargeting('cst_section',["sports","homepage"]).setTargeting('kw',[]).setTargeting('category',[]).setTargeting('cst_topic',[]).setTargeting('pageType',"home-front").setTargeting("referrer", "https://www.google.com/").setTargeting('build',"fishburne").setTargeting("title", sdpTargeting.title).setTargeting("targetPaths", sdpTargeting.targetPaths).setTargeting("fullPath", sdpTargeting.fullPath).setTargeting("queryStr", sdpTargeting.queryStr).setTargeting("domainName", sdpTargeting.domainName) ).setTargeting("position", ["sponsor_logo"]);					window.usat_ad_tags['lawrence_dfp_desktop_top'] = {"url":"","priority":10,"operator":"OR","toggle":1,"lazy_load":0,"refresh_enabled":1,"conditionals":[{"function":"is_home","arguments":[""]}],"url_vars":{"tag":"lawrence_dfp_desktop_top","sizes":["fluid",{"width":"728","height":"90"},{"width":"970","height":"66"},{"width":"970","height":"250"},{"width":"1000","height":"250"},{"width":"2560","height":"1440"}],"device_target":"desktop","tag_id":"div-gpt-ad-1383692344899-5","dfp_id":"7103","tag_name":"SMG_MMAJunkie\/728x90_flex\/sports\/mma\/main"}};
# 					window.lawrence_dfp_desktop_top = googletag.defineSlot("/7103/SMG_MMAJunkie/728x90_flex/sports/mma/main", ['fluid',[728,90],[970,66],[970,250],[1000,250],[2560,1440]], "acm-ad-tag-lawrence_dfp_desktop_top").addService(googletag.pubads().setTargeting('cst_subsection',[]).setTargeting('ssts_subsection',[]).setTargeting('cst_section',["sports","homepage"]).setTargeting('kw',[]).setTargeting('category',[]).setTargeting('cst_topic',[]).setTargeting('pageType',"home-front").setTargeting("referrer", "https://www.google.com/").setTargeting('build',"fishburne").setTargeting("title", sdpTargeting.title).setTargeting("targetPaths", sdpTargeting.targetPaths).setTargeting("fullPath", sdpTargeting.fullPath).setTargeting("queryStr", sdpTargeting.queryStr).setTargeting("domainName", sdpTargeting.domainName) ).setTargeting("position", ["728x90_flex"]).setTargeting("nsf", ["paramount", "paramount-16_9"]);					window.usat_ad_tags['lawrence_dfp_desktop_top_300x250'] = {"url":"","priority":10,"operator":"OR","toggle":"1","lazy_load":0,"refresh_enabled":1,"conditionals":[{"function":"is_home","arguments":[""]}],"url_vars":{"tag":"lawrence_dfp_desktop_top_300x250","sizes":[{"width":"300","height":"250"},{"width":"300","height":"600"}],"device_target":"desktop","tag_id":"div-gpt-ad-1383692344899-1","dfp_id":"7103","tag_name":"SMG_MMAJunkie\/300x250_1a\/sports\/mma\/main"}};
# 					window.lawrence_dfp_desktop_top_300x250 = googletag.defineSlot("/7103/SMG_MMAJunkie/300x250_1a/sports/mma/main", [[300,250],[300,600]], "acm-ad-tag-lawrence_dfp_desktop_top_300x250").addService(googletag.pubads().setTargeting('cst_subsection',[]).setTargeting('ssts_subsection',[]).setTargeting('cst_section',["sports","homepage"]).setTargeting('kw',[]).setTargeting('category',[]).setTargeting('cst_topic',[]).setTargeting('pageType',"home-front").setTargeting("referrer", "https://www.google.com/").setTargeting('build',"fishburne").setTargeting("title", sdpTargeting.title).setTargeting("targetPaths", sdpTargeting.targetPaths).setTargeting("fullPath", sdpTargeting.fullPath).setTargeting("queryStr", sdpTargeting.queryStr).setTargeting("domainName", sdpTargeting.domainName) ).setTargeting("position", ["300x250_1a"]);					window.usat_ad_tags['lawrence_dfp_desktop_bottom_300x250'] = {"url":"","priority":10,"operator":"OR","toggle":"1","lazy_load":0,"refresh_enabled":1,"conditionals":[{"function":"is_home","arguments":[""]}],"url_vars":{"tag":"lawrence_dfp_desktop_bottom_300x250","sizes":[{"width":"300","height":"250"},{"width":"300","height":"600"}],"device_target":"desktop","tag_id":"div-gpt-ad-1383692344899-3","dfp_id":"7103","tag_name":"SMG_MMAJunkie\/300x250_2a\/sports\/mma\/main"}};
# 					window.lawrence_dfp_desktop_bottom_300x250 = googletag.defineSlot("/7103/SMG_MMAJunkie/300x250_2a/sports/mma/main", [[300,250],[300,600]], "acm-ad-tag-lawrence_dfp_desktop_bottom_300x250").addService(googletag.pubads().setTargeting('cst_subsection',[]).setTargeting('ssts_subsection',[]).setTargeting('cst_section',["sports","homepage"]).setTargeting('kw',[]).setTargeting('category',[]).setTargeting('cst_topic',[]).setTargeting('pageType',"home-front").setTargeting("referrer", "https://www.google.com/").setTargeting('build',"fishburne").setTargeting("title", sdpTargeting.title).setTargeting("targetPaths", sdpTargeting.targetPaths).setTargeting("fullPath", sdpTargeting.fullPath).setTargeting("queryStr", sdpTargeting.queryStr).setTargeting("domainName", sdpTargeting.domainName) ).setTargeting("position", ["300x250_2a"]);					window.usat_ad_tags['lawrence_dfp_desktop_native'] = {"url":"","priority":10,"operator":"OR","toggle":1,"lazy_load":0,"refresh_enabled":1,"conditionals":[{"function":"is_home","arguments":[""]}],"url_vars":{"tag":"lawrence_dfp_desktop_native","sizes":["fluid",{"width":"3","height":"1"}],"device_target":"desktop","tag_id":"div-gpt-ad-1383692344899-9","dfp_id":"7103","tag_name":"SMG_MMAJunkie\/native\/sports\/mma\/main"}};
# 					window.lawrence_dfp_desktop_native = googletag.defineSlot("/7103/SMG_MMAJunkie/native/sports/mma/main", ['fluid',[3,1]], "acm-ad-tag-lawrence_dfp_desktop_native").addService(googletag.pubads().setTargeting('cst_subsection',[]).setTargeting('ssts_subsection',[]).setTargeting('cst_section',["sports","homepage"]).setTargeting('kw',[]).setTargeting('category',[]).setTargeting('cst_topic',[]).setTargeting('pageType',"home-front").setTargeting("referrer", "https://www.google.com/").setTargeting('build',"fishburne").setTargeting("title", sdpTargeting.title).setTargeting("targetPaths", sdpTargeting.targetPaths).setTargeting("fullPath", sdpTargeting.fullPath).setTargeting("queryStr", sdpTargeting.queryStr).setTargeting("domainName", sdpTargeting.domainName) ).setTargeting("position", ["native"]);window.wasabiAsyncStickAd = false;
# if ( ! window.hasOwnProperty( 'wasabiAsyncStickCallback' ) ) {
# 	window.wasabiAsyncStickCallback = function() {
# 		'use strict';
# 		window.wasabiAsyncStickAd = true;
# 	};
# }
# 	googletag.pubads().setTargeting('referrer', "https://www.google.com/")
# if ( null !== localStorage.getItem( 'kxgannett_kuid' ) ) {
# 	googletag.pubads().setTargeting( 'kxgannett_kuid', localStorage.getItem( 'kxgannett_kuid' ) );
# }
# googletag.pubads().setTargeting( 'features', 'noautoplay' );
# googletag.pubads().setTargeting( 'topic', window.dfpTargetingObject.kw );
# googletag.pubads().enableSingleRequest();
# googletag.pubads().enableLazyLoad({"fetchMarginPercent": 500,"renderMarginPercent": 10,"mobileScaling": 2.0});
# if( 'undefined' !== typeof bidManager && bidManager ) {
# 	bidManager.initialize();
# }
#
# googletag.enableServices();
#
# });
# </script>
# <script>
#     var PushlySDK = window.PushlySDK || [];
#     function pushly() { PushlySDK.push(arguments) }
#     pushly('load', {
#         domainKey: decodeURIComponent("yIOCElxAPfOsogmbs9ZZewEOZKLbhRRdcYTd"),
#         sw: "/wp-content/plugins/pushly/assets/js/pushly-sdk-worker.js.php",
#         swScope: "/wp-content/plugins/pushly/"    });
# </script>
# <style type="text/css">
# a:hover {
#   color: #6587b9;
# }
# blockquote:not(.twitter-tweet):not(.tiktok-embed):not(.pq) p:before {
#   background-color: #6587b9;
# }
# .wp-core-ui .admin-fishburne .button,
# .button,
# .wp-core-ui .admin-fishburne .button--primary,
# .button--primary {
#   background-color: #6587b9;
# }
# .border-link {
#   border-bottom: 2px solid #6587b9;
# }
# .border-link:hover {
#   color: #6587b9;
# }
# .admin-fishburne .module-title span:after,
# .module-title span:after {
#   border-top: 8px solid #6587b9;
# }
# html #wrapper #wrapper--holder .color-primary {
#   color: #6587b9;
# }
# html #wrapper #wrapper--holder .background-color-primary {
#   background-color: #6587b9;
# }
# html #wrapper #wrapper--holder .border-color-primary {
#   border-color: #6587b9;
# }
# .page__content ul>li:before,
# .entry__content ul>li:before {
#   color: #6587b9;
# }
# .page__content ol>li:before,
# .entry__content ol>li:before {
#   color: #6587b9;
# }
# .page__content a,
# .entry__content a {
#   border-bottom: 2px solid #6587b9;
# }
# .page__content a:hover,
# .entry__content a:hover {
#   color: #6587b9;
# }
# .entry__title__more-link span:not(.icon) {
#   border-bottom: 2px solid #6587b9;
# }
# .entry__title__more-link .icon,
# .entry__title__more-link:hover {
#   color: #6587b9;
# }
# .shortcode--related .related .block.block:hover,
# .ad .block.block:hover {
#   color: #6587b9;
# }
# .shortcode--listicle .shortcode--listicle__header span:after,
# .shortcode--vertical-gallery .shortcode--vertical-gallery__header span:after {
#   border-top: 8px solid #6587b9;
# }
# .listicle__overlay,
# .vertical-gallery__overlay {
#   background: #6587b9;
# }
# #primary blockquote.pq {
#   border-top: 8px solid #6587b9;
#   border-left: 8px solid #6587b9;
#   border-right: 8px solid #6587b9;
#   border-bottom: 8px solid #6587b9;
# }
# .widget-area.sidebar .widget .heading-small h2:after,
# .widget-area.sidebar--follow .widget .heading-small h2:after,
# background black .widget .heading-small h2:after {
#   border-top: 8px solid #6587b9;
# }
# #ad--native-wrapper article .content .meta-info .tl-clickthrough-url {
#   color: #6587b9;
# }
# #ad--native-wrapper article .content .hero__label.tl-clickthrough-url {
#   border-bottom: 2px solid #6587b9;
# }
# #ad--native-wrapper article .content .hero__label.tl-clickthrough-url:hover {
#   color: #6587b9;
# }
# #hero .bundle-title span:after,
# .widget-archive .bundle-title span:after {
#   border-top: 8px solid #6587b9;
# }
# #hero .bundle .post--bundle .post__meta__category,
# .widget-archive .bundle .post--bundle .post__meta__category {
#   color: #6587b9;
# }
# .bundle-fw-posts-right-heading {
#   border-top: 8px solid #6587b9;
# }
# .header--brand .header {
#   background: #6587b9;
# }
# .header__logos .branding__logo {
#   max-height: 32px;
# }
# .header__nav>ul>li:hover {
#   color: #6587b9;
#   box-shadow: inset 0 4px 0 0 #6587b9;
# }
# .header__nav>ul>li .icon--arrow-down {
#   color: #6587b9;
# }
# .header__nav>ul>li ul>li a:hover {
#   color: #6587b9;
# }
# .header__nav>ul>li ul>li:hover>a {
#   color: #6587b9;
# }
# .header__nav .nav__vault:hover {
#   color: #6587b9;
#   box-shadow: inset 0 4px 0 0 #6587b9;
# }
# .header__nav .dashicons-arrow-down-alt2 {
#   color: #6587b9;
# }
# .header__share__trigger--open .icon {
#   color: #6587b9;
# }
# .header__mobile__trigger .dashicons {
#   color: #6587b9;
# }
# .header__mobile__content__nav .menu-item a .icon {
#   color: #6587b9;
# }
# .header--mobile_sidescroll .header__nav ul li a:hover,
# .header--mobile_sidescroll .header__nav ul li ul.sub-menu a:hover,
# .header--mobile_sidescroll .header__nav ul li.current-menu-item a,
# .header--mobile_sidescroll .header__nav ul li.current-menu-parent > a {
#   box-shadow: 0 4px 2px -2px #6587b9;
# }
# .header--mobile_sidescroll .header__mobile__navigation > ul > li.current-menu-item,
# .header--mobile_sidescroll .header__mobile__navigation > ul > li.current-menu-parent {
#   border-bottom: 4px solid #6587b9;
# }
# .header--mobile_sidescroll .header__mobile__navigation ul li.hover {
#   border-bottom: 4px solid #6587b9;
# }
# .header--mobile_sidescroll .header__mobile__navigation ul.sub-menu li.current-menu-item a {
#   border-bottom: 4px solid #6587b9;
# }
# .article__author .author {
#   border-bottom: 2px solid #6587b9;
# }
# .article__author .author:hover {
#   color: #6587b9;
# }
# .subnav__navigation .dashicons-arrow-down-alt2 {
#   color: #6587b9;
# }
# .subnav__navigation ul li.current-menu-item {
#   border-bottom: 2px solid #6587b9;
# }
# .subnav__navigation ul li a .icon,
# .subnav__navigation ul li button .icon {
#   color: #6587b9;
# }
# .subnav__navigation ul li.hover.menu-item-has-children {
#   border-top: 2px solid #6587b9;
# }
# #footer .footer__blog__link__image {
#   height: 32px;
# }
# #footer .footer__legal__menu .menu-item a:hover {
#   border-bottom: 2px solid #6587b9;
# }
# .post--extended-scroll .post__more__link {
#   border-bottom: 2px solid #6587b9;
# }
# .post--extended-scroll .post__more__link:hover {
#   color: #6587b9;
# }
# .post--extended-scroll .post__more__link .icon {
#   color: #6587b9;
# }
# .post--auto-related:hover {
#   color: #6587b9;
# }
# .related .post--auto-related .post__title a {
#   border-bottom: 2px solid #6587b9;
# }
# .post__thumbnail__icon {
#   background: #6587b9;
# }
# .post--stream .post__category {
#   color: #6587b9;
# }
# #infinite-scroll-container .block .meta-info .category {
#   color: #6587b9;
# }
# .related__link {
#   border-bottom: 2px solid #6587b9;
# }
# .related__link:hover {
#   color: #6587b9;
# }
# .auto-related__link {
#   border-bottom: 2px solid #6587b9;
# }
# .auto-related__link:hover {
#   color: #6587b9;
# }
# #sidebar .auto-related .related__title span:after {
#   border-top: 8px solid #6587b9;
# }
# .megablock-related--sidescroll .slick-dots .slick-active button {
#   background-color: #6587b9;
# }
# .megablock-related--sidescroll__nav-item.slick-current {
#   background-color: #6587b9;
# }
# .megablock-related--primary > .post > .post__title:hover h3,
# .megablock-related--primary > .post > .post__title:focus h3 {
#   color: #6587b9;
# }
# .megablock-related--primary .post__meta__category a {
#   color: #6587b9;
# }
# .megablock-related--secondary .related__title a {
#   background-color: #6587b9;
# }
# .parsely .posts-parsely .parsely__post_meta .parsely__post_section {
#   color: #6587b9;
# }
# .breaking-news__wrapper {
#   background-color: #6587b9;
# }
# .breaking-news__title {
#   background-color: #6587b9;
# }
# .breaking-news__spacer:before {
#   background-color: #6587b9;
#   color: #6587b9;
# }
# .widget .newsletter__email__submit {
#   background-color: #6587b9;
# }
# .newsletter__viewall__link {
#   border-bottom: 2px solid #6587b9;
# }
# .newsletter--footer .newsletter__email__submit {
#   background-image: linear-gradient(to bottom, #6587b9, #6587b9), linear-gradient(to bottom, rgba(0,0,0,0), rgba(0,0,0,0.12));
# }
# .newsletter-modal:before {
#   border-top: 8px solid #6587b9;
# }
# .newsletter-modal .newsletter_form .newsletter__input-icon {
#   color: #6587b9;
# }
# .newsletter-modal .newsletter_form .newsletter__button {
#   background-image: linear-gradient(to bottom, #6587b9, #6587b9), linear-gradient(to bottom, rgba(0,0,0,0), rgba(0,0,0,0.12));
# }
# .vertical-gallery--caption-link .vertical-gallery--caption-link-a {
#   color: #6587b9;
# }
# a.pagination__link:hover {
#   border: 1px solid #6587b9;
#   color: #6587b9;
# }
# .pagination__link .icon {
#   color: #6587b9;
# }
# .pagination__number:not(.pagination__number--current):hover {
#   border: 1px solid #6587b9;
#   color: #6587b9;
# }
# .pagination__number--current {
#   background: #6587b9;
# }
# .listicles .listicle-header:not(.with-count):before {
#   border-top: 8px solid #6587b9;
# }
# .listicles .listicle-header.with-count .listicle-count {
#   background-color: #6587b9;
# }
# .modal__container:before {
#   border-top: 8px solid #6587b9;
# }
# .home-content[data-show="1"] .home-content__toggle__link[data-tab="1"] {
#   border-top: 8px solid #6587b9;
# }
# .home-content[data-show="2"] .home-content__toggle__link[data-tab="2"] {
#   border-top: 8px solid #6587b9;
# }
# .smg-event--icon {
#   background-color: #6587b9;
# }
# .events-category-nav a.catnav_link:hover,
# .events-category-nav a.catnav_link.active {
#   color: #6587b9;
# }
# .fishburne-vertical-gallery.single-related .heading-small h2 {
#   border-top: 8px solid #6587b9;
# }
# .fishburne-vertical-gallery.single-related .vertical-gallery--icon {
#   background-color: #6587b9;
# }
# .event-date {
#   background-color: #6587b9;
# }
# .event-group-label {
#   background-color: #6587b9;
# }
# .event-row {
#   border-top: 0.0625rem solid #6587b9;
# }
# .event-versus {
#   background-color: #6587b9;
# }
# .brackets .pool-preview,
# .brackets .bracket-preview {
#   box-shadow: inset 0 -4px 0 #6587b9;
# }
# .brackets .pool-preview h4 a,
# .brackets .bracket-preview h4 a {
#   border-bottom: 2px solid #6587b9;
# }
# .brackets .share-link a,
# .brackets .page-bracket-description a,
# .brackets .bracket__results a,
# .brackets .module__header__links a,
# .brackets .module__header__links button,
# .brackets .more-link {
#   border-bottom: 2px solid #6587b9;
# }
# .brackets .toggle-switch-button--active {
#   box-shadow: inset 0 -4px 0 #6587b9;
# }
# .brackets .bracket-mobile-nav__item--active button:after {
#   background: #6587b9;
# }
# .brackets .pool__pool-rankings caption {
#   background-color: #6587b9;
# }
# .mmaj-event__date,
# .mmaj-ranking__rank {
#   color: #6587b9;
# }
# .mmaj-rankings__title--honorable,
# .mmaj-event__vs {
#   background-color: #6587b9;
# }
# .mmaj-rankings__title {
#   border-bottom: 1px solid #6587b9;
# }
# .mmaj-rankings__nav {
#   border-top: 1px solid #6587b9;
# }
# </style>
# <style type="text/css">
# :root {
# 	--c-primary: #6587b9;
# }
# </style>
#
# <!-- Jetpack Open Graph Tags -->
# <meta property="og:type" content="website" />
# <meta property="og:title" content="MMA Junkie" />
# <meta property="og:description" content="UFC and MMA news, rumors, live blogs and videos" />
# <meta property="og:url" content="https://mmajunkie.usatoday.com/" />
# <meta property="og:site_name" content="MMA Junkie" />
# <meta property="og:image" content="https://mmajunkie.usatoday.com/wp-content/uploads/sites/91/2013/11/cropped-mmajunkie-logo-icon.jpg" />
# <meta property="og:image:width" content="512" />
# <meta property="og:image:height" content="512" />
# <meta property="og:image:alt" content="" />
# <meta property="og:locale" content="en_US" />
# <meta property="fb:pages" content="105550656158763" />
#
# <!-- End Jetpack Open Graph Tags -->
# <link rel="icon" href="https://mmajunkie.usatoday.com/wp-content/uploads/sites/91/2013/11/cropped-mmajunkie-logo-icon.jpg?w=32" sizes="32x32" />
# <link rel="icon" href="https://mmajunkie.usatoday.com/wp-content/uploads/sites/91/2013/11/cropped-mmajunkie-logo-icon.jpg?w=192" sizes="192x192" />
# <link rel="apple-touch-icon" href="https://mmajunkie.usatoday.com/wp-content/uploads/sites/91/2013/11/cropped-mmajunkie-logo-icon.jpg?w=180" />
# <meta name="msapplication-TileImage" content="https://mmajunkie.usatoday.com/wp-content/uploads/sites/91/2013/11/cropped-mmajunkie-logo-icon.jpg?w=270" />
# 		<style type="text/css" id="wp-custom-css">
# 			/*#post-193687 + .container + .container.single-related {
# 	display: none;
# }
#
# #post-193687 + .container + .container + .single-related.container--comments {
# 	display: none;
# }*/
# #post-193687 + .container + .container + .container + .container.column.container--stories .play-overlay {
# 	display: none;
# }
#
# #post-193687 + .container + .container + .container + .container.column.container--stories .img-holder .meta {
# 	display: none;
# }
#
# #acm-ad-tag-lawrence_dfp_desktop_skin {
# 	position: static;
# }		</style>
#
# 	<script type="text/javascript">
# 		var is_user_logged_in = 0;
# 		var usat_site_env = "production";
# 		window.addEventListener('skinCreativeEvent', function(e) {
# 			setTimeout(() => {
# 				if (typeof(Event) === 'function') {
# 					// modern browsers
# 					window.dispatchEvent(new Event('resize'));
# 				} else {
# 					// for IE and other old browsers
# 					// causes deprecation warning on modern browsers
# 					var evt = window.document.createEvent('UIEvents');
# 					evt.initUIEvent('resize', true, false, window, 0);
# 					window.dispatchEvent(evt);
# 				}
# 			}, 100);
# 		});
# 	</script>
#
# </head>
#
# <body class="home blog mmajunkie theme-fishburne">
#
#
# <div id='acm-ad-tag-lawrence_dfp_desktop_skin' style='width:1px; height:1px;'><script type='text/javascript'>googletag.cmd.push(function(e) { googletag.display('acm-ad-tag-lawrence_dfp_desktop_skin'); });</script></div><div id='acm-ad-tag-lawrence_dfp_desktop_interstitial' style='width:%width%px; height:%height%px;'><script type='text/javascript'>googletag.cmd.push(function(e) { googletag.display('acm-ad-tag-lawrence_dfp_desktop_interstitial'); });</script></div><div id="wrapper">
# 		<div id="wrapper--holder" class="wrapper--holder--colored-header">
# 		<div class="noskim" style="">
# 						<div class="header__wrapper header--brand">
# 	<header id="header" class="header" role="banner">
# 		<div class="header__container">
# 			<span class="header__logos">
# 									<a
# 						href="https://mmajunkie.usatoday.com"
# 						title="MMA Junkie"
# 						class="branding__logo-link  "
# 					>
# 						<img
# 							src="https://mmajunkie.usatoday.com/wp-content/uploads/sites/91/2017/07/mmaj-header-logo.png?w=659"
# 							alt="MMA Junkie"
# 							class="branding__logo"
# 							height="32"
# 							width="251"
# 						>
# 													<img
# 								src="https://mmajunkie.usatoday.com/wp-content/uploads/sites/91/2016/04/mmaj-archive-icon.png?w=88"
# 								alt="MMA Junkie"
# 								class="branding__logo--mobile"
# 								height="32"
# 								width="46"
# 							>
# 											</a>
#
# 							</span>
#
#
# 			<nav class="header__nav" role="navigation">
# 				<ul>
# 					<li id="menu-item-243388" class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-has-children menu-item-243388"><a href="https://mmajunkie.usatoday.com/category/news">News <span class="icon icon--arrow-down"><svg viewBox="0 0 24 24"><use href="#arrow"></use></svg></span></a>
# <ul class="sub-menu">
# 	<li id="menu-item-414129" class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-414129"><a href="https://mmajunkie.usatoday.com/category/bluecorner">Blue Corner</a></li>
# 	<li id="menu-item-446591" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-446591"><a href="https://boxingjunkie.usatoday.com/">Boxing</a></li>
# </ul>
# </li>
# <li id="menu-item-64121" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-64121"><a href="/schedule">Schedule</a></li>
# <li id="menu-item-64100" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-64100"><a href="/results">Results</a></li>
# <li id="menu-item-64101" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-64101"><a href="/rankings">Rankings <span class="icon icon--arrow-down"><svg viewBox="0 0 24 24"><use href="#arrow"></use></svg></span></a>
# <ul class="sub-menu">
# 	<li id="menu-item-64103" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-64103"><a href="/fighters">Fighters</a></li>
# </ul>
# </li>
# <li id="menu-item-64122" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-64122"><a href="/category/videos">Videos</a></li>
# <li id="menu-item-64123" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-64123"><a href="/radio">Radio</a></li>
# <li id="menu-item-682931" class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-682931"><a href="https://mmajunkie.usatoday.com/category/trivia">Trivia</a></li>
# ...
# <script id='jetpack-stats-js-after'>
# _stq = window._stq || [];
# _stq.push([ "view", {v:'ext',blog:'175785130',post:'0',tz:'-4',srv:'mmajunkie.usatoday.com',hp:'vip',j:'1:12.2.1'} ]);
# _stq.push([ "clickTrackerInit", "175785130", "0" ]);
# </script>
# <script src='https://s.skimresources.com/js/77560X1528128.skimlinks.js' id='skimlinks-js'></script>
# <script async src='https://cdn.p-n.io/pushly-sdk.min.js?domain_key=yIOCElxAPfOsogmbs9ZZewEOZKLbhRRdcYTd&#038;ver=6.2.2' id='pushly-sdk-js'></script>
# 			</div>
# 		</div><!-- Wrapper Holder -->
# 	</div><!-- Wrapper -->
# </body>
# </html>
#
#
# <!--
# $$\
# $$ |
# $$ |      $$$$$$\  $$\  $$\  $$\  $$$$$$\   $$$$$$\  $$$$$$$\   $$$$$$$\  $$$$$$\
# $$ |      \____$$\ $$ | $$ | $$ |$$  __$$\ $$  __$$\ $$  __$$\ $$  _____|$$  __$$\
# $$ |      $$$$$$$ |$$ | $$ | $$ |$$ |  \__|$$$$$$$$ |$$ |  $$ |$$ /      $$$$$$$$ |
# $$ |     $$  __$$ |$$ | $$ | $$ |$$ |      $$   ____|$$ |  $$ |$$ |      $$   ____|
# $$$$$$$$\$$$$$$$ |\$$$$$\$$$$  |$$ |      \$$$$$$$\ $$ |  $$ |\$$$$$$$\ \$$$$$$$\
# \________|\_______| \_____\____/ \__|       \_______|\__|  \__| \_______| \_______|
#
# Brought to you by your good friends at USA Today Sports.
# -->
# <div id="fishburne-svgs" style="display: none;">
# 	<svg xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24">
#     <defs>
#         <symbol id="audio">
#             <path d="M17 15v6c0 1.1.9 2 2 2s2-.9 2-2v-6c0-1.1-.9-2-2-2s-2 .9-2 2M3 15v6c0 1.1.9 2 2 2s2-.9 2-2v-6c0-1.1-.9-2-2-2s-2 .9-2 2m20.2 2.8c.44 0 .8-.38.8-.84V13.6C24 6.54 18.86 1 12.3 1 5.63 1 0 6.77 0 13.6v3.36c0 .46.36.84.8.84.44 0 .8-.38.8-.84V13.6c0-5.92 4.9-10.92 10.7-10.92 5.66 0 10.1 4.8 10.1 10.92v3.36c0 .46.36.84.8.84"/>
#         </symbol>
#     </defs>
#     <g fill="none" fill-rule="evenodd">
#         <mask id="b" fill="#fff">
#             <use href="#audio"/>
#         </mask>
#         <use fill="#FFF" href="#audio"/>
#         <g fill="#000" mask="url(#b)">
#             <path d="M0 1h24v24H0z"/>
#         </g>
#     </g>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24">
#     <defs>
#         <symbol id="close">
#             <path d="M16.605 4l-4.521 4.606L7.394 4 4 7.394 8.69 12 4 16.605 7.394 20l4.69-4.605L16.605 20 20 16.605 15.48 12 20 7.394z"/>
#         </symbol>
#     </defs>
#     <g fill="none" fill-rule="evenodd">
#         <mask id="b" fill="#fff">
#             <use href="#close"/>
#         </mask>
#         <use fill="#000" href="#close"/>
#     </g>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24">
#     <defs>
#         <symbol id="gallery">
#             <path d="M0 2h16.8v14.4H0V2zm23.996 7.194V18.8H24v2.396h-.004v.004H21.6v-.004H7.2V18.8h14.4V9.194h-2.4V6.798H24v2.396h-.004z"/>
#         </symbol>
#     </defs>
#     <g fill="none" fill-rule="evenodd">
#         <mask id="b" fill="#fff">
#             <use href="#gallery"/>
#         </mask>
#         <use fill="#FFF" href="#gallery"/>
#         <g fill="#000" mask="url(#b)">
#             <path d="M0 1h24v24H0z"/>
#         </g>
#     </g>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24">
#     <defs>
#         <symbol id="play">
#             <path d="M22.593 10.527L5.64.346C4.304-.46 3 .192 3 1.802V22.2c0 1.613 1.302 2.263 2.64 1.457L22.56 13.475c1.336-.806 1.354-2.142.034-2.948"/>
#         </symbol>
#     </defs>
#     <g fill="none" fill-rule="evenodd">
#         <mask id="b" fill="#fff">
#             <use href="#play"/>
#         </mask>
#         <use fill="#FFF" href="#play"/>
#         <g fill="#000" mask="url(#b)">
#             <path d="M0 1h24v24H0z"/>
#         </g>
#     </g>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24">
#     <defs>
#         <symbol id="podcast">
#             <path d="M16.667 7c0 5.833-1.75 8.333-5 8.333-3.259 0-5-1.666-5-8.333H5c0 7.5 2.5 10 5.833 10v3.342c-2.825.058-5 .408-5 .825 0 .458 2.609.833 5.834.833 3.225 0 5.833-.375 5.833-.833 0-.417-2.175-.767-5-.825V17c2.5 0 5.833-2.5 5.833-10h-1.666zm-5 6.667C13.742 13.667 15 12.025 15 9.5h-3.333v-.833H15v-.834h-3.333V7H15v-.833h-3.333v-.834h3.283C14.692 3.292 13.5 2 11.667 2 9.592 2 8.333 3.642 8.333 6.167V9.5c0 2.525 1.259 4.167 3.334 4.167z"/>
#         </symbol>
#     </defs>
#     <g fill="none" fill-rule="evenodd">
#         <mask id="b" fill="#fff">
#             <use href="#podcast"/>
#         </mask>
#         <use fill="#F03C4B" href="#podcast"/>
#     </g>
# </svg>
# <?xml version="1.0" encoding="UTF-8"?>
# <svg id="listicle" width="24" height="24" viewBox="0 0 16 15" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#     <defs>
#         <polygon id="listicle-path-1" points="0 14.9845161 15.8330645 14.9845161 15.8330645 0 0 0"></polygon>
#     </defs>
#     <g stroke="none" stroke-width="1" fill="none" fill-rule="evenodd">
# 		<path d="M1.65458468,1.20967742e-05 C0.740794355,1.20967742e-05 2.82258065e-05,0.740778226 2.82258065e-05,1.65456855 C2.82258065e-05,2.56835887 0.740794355,3.309125 1.65458468,3.309125 C2.56833468,3.309125 3.30910081,2.56835887 3.30910081,1.65456855 C3.30910081,0.740778226 2.56833468,1.20967742e-05 1.65458468,1.20967742e-05" id="listicle-fill-1" fill="#FEFEFE"></path>
# 		<path d="M1.65458468,5.87358065 C0.740794355,5.87358065 2.82258065e-05,6.61434677 2.82258065e-05,7.5281371 C2.82258065e-05,8.44192742 0.740794355,9.18269355 1.65458468,9.18269355 C2.56833468,9.18269355 3.30910081,8.44192742 3.30910081,7.5281371 C3.30910081,6.61434677 2.56833468,5.87358065 1.65458468,5.87358065" id="listicle-fill-3" fill="#FEFEFE"></path>
# 		<path d="M1.65458468,11.6754073 C0.740794355,11.6754073 2.82258065e-05,12.4161734 2.82258065e-05,13.3299637 C2.82258065e-05,14.2437137 0.740794355,14.9844798 1.65458468,14.9844798 C2.56833468,14.9844798 3.30910081,14.2437137 3.30910081,13.3299637 C3.30910081,12.4161734 2.56833468,11.6754073 1.65458468,11.6754073" id="listicle-fill-5" fill="#FEFEFE"></path>
# 		<mask id="listicle-mask-1" fill="white">
# 			<use xlink:href="#listicle-path-1"></use>
# 		</mask>
# 		<g id="listicle-clip-8"></g>
# 		<polygon id="listicle-fill-7" fill="#FEFEFE" mask="url(#listicle-mask-1)" points="5.43548387 2.85048387 15.8330645 2.85048387 15.8330645 0.487419355 5.43548387 0.487419355"></polygon>
# 		<polygon id="listicle-fill-9" fill="#FEFEFE" mask="url(#listicle-mask-1)" points="5.43548387 14.4971371 15.8330645 14.4971371 15.8330645 12.1340726 5.43548387 12.1340726"></polygon>
# 		<polygon id="listicle-fill-10" fill="#FEFEFE" mask="url(#listicle-mask-1)" points="5.43548387 8.62318548 15.8330645 8.62318548 15.8330645 6.26012097 5.43548387 6.26012097"></polygon>
#     </g>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="24" height="24" viewBox="0 0 24 24">
#     <defs>
#         <path id="thumbsup" d="M4 13.687v4.872c0 .383.313.696.696.696.383 0 .696-.313.696-.696v-4.872c0-.383-.313-.696-.696-.696-.383 0-.696.313-.696.696zm9.284-3.48h-.605c-.042.007-.077 0-.077 0h.077c.215-.034.779-.396.153-3.41-.752-3.653-2.22-2.68-2.22-2.68s-.355 2.639-.39 3.09c-.16 1.908-2.478 4.873-2.478 4.873 0 .243-1.656.584-1.656.835.014 2.143 0 3.98 0 6.2 1.545-.417 2.373.516 5.679.516 1.079 0 2.429-.181 3.563-.376h2.304c.522-.056 1.35-.258 1.482-1.01.09-.521-.348-.939-.717-1.078h.376c.585-.063 1.037-.71.974-1.392-.062-.585-.626-1.113-1.113-1.197 0 0 1.37-.132 1.364-1.17 0-.688-.661-1.182-1.322-1.113h-.376c.577-.062.995-.66.925-1.35-.07-.682-.591-1.301-1.176-1.239l-4.767.501z"/>
#     </defs>
#     <g fill="none" fill-rule="evenodd" opacity=".3">
#         <g>
#             <g>
#                 <g>
#                     <g>
#                         <g transform="translate(-625 -800) translate(466 349) translate(137 435) translate(22 8) matrix(1 0 0 -1 0 32)">
#                             <mask id="az9aw64f0b" fill="#fff">
#                                 <use xlink:href="#thumbsup"/>
#                             </mask>
#                             <use fill="#000" xlink:href="#thumbsup"/>
#                             <g fill="#000" mask="url(#az9aw64f0b)">
#                                 <path d="M0 0H24V24H0z"/>
#                                 <path d="M0 1H24V25H0z"/>
#                             </g>
#                         </g>
#                     </g>
#                 </g>
#             </g>
#         </g>
#     </g>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24">
#     <defs>
#         <symbol id="arrow">
#             <path d="M17.529 7l-5.637 5.638L6.362 7.1 4 9.471l7.992 7.992.008-.007v.007l8-7.992z"/>
#         </symbol>
#     </defs>
#     <g fill="none" fill-rule="evenodd">
#         <mask id="b" fill="#fff">
#             <use href="#arrow"/>
#         </mask>
#         <use fill="#000" href="#arrow"/>
#     </g>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24">
#     <defs>
#         <symbol id="search">
#             <path d="M9.756 4.365c2.957 0 5.365 2.383 5.365 5.313 0 .991-.287 1.957-.817 2.809l-.487.774-.687.547a5.335 5.335 0 0 1-3.374 1.183c-2.965 0-5.365-2.383-5.365-5.313 0-2.93 2.4-5.313 5.365-5.313m0-2.365C5.47 2 2 5.435 2 9.678s3.47 7.678 7.756 7.678a7.775 7.775 0 0 0 4.878-1.713c.061.105.114.218.21.305l4.825 4.79c.27.262.618.392.965.392.348 0 .696-.13.966-.4.53-.522.53-1.383 0-1.904l-4.826-4.791a1.504 1.504 0 0 0-.453-.296 7.53 7.53 0 0 0 1.183-4.06C17.504 5.434 14.034 2 9.756 2" />
#         </symbol>
#     </defs>
#     <g fill="none" fill-rule="evenodd">
#         <mask id="b" fill="#fff">
#             <use href="#search"/>
#         </mask>
#         <use fill="#000" href="#search"/>
#     </g>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24">
#     <defs>
#         <symbol id="arrow-right-2">
#             <path d="M17.086 12.707H3v-2h14.086l-3.293-3.293L15.207 6l5.707 5.707-5.707 5.707L13.793 16l3.293-3.293z"/>
#         </symbol>
#     </defs>
#     <g fill="none" fill-rule="evenodd">
#         <mask id="b" fill="#000">
#             <use href="#arrow-right-2"/>
#         </mask>
#         <use fill="#000" fill-rule="nonzero" href="#arrow-right-2"/>
#     </g>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24">
#     <defs>
#         <symbol id="share">
#             <path d="M22 10.714L14.857 5v2.857C2 7.857 2 17.857 2 19.286c2.857-5.715 11.429-5.715 12.857-5.715v2.858L22 10.714z"/>
#         </symbol>
#     </defs>
#     <g fill="none" fill-rule="evenodd">
#         <mask id="b" fill="#fff">
#             <use href="#share"/>
#         </mask>
#         <use fill="#000" href="#share"/>
#     </g>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24">
#     <defs>
#         <symbol id="facebook">
#             <path d="M3.993 21A.993.993 0 0 1 3 20.006V3.993C3 3.445 3.445 3 3.993 3h16.014c.548 0 .993.445.993.993v16.013a.994.994 0 0 1-.993.994H15.42v-6.97h2.34l.35-2.717h-2.69V9.578c0-.786.218-1.322 1.346-1.322h1.438v-2.43a19.23 19.23 0 0 0-2.096-.107c-2.074 0-3.494 1.266-3.494 3.59v2.004H10.27v2.716h2.345V21h-8.62z"/>
#         </symbol>
#     </defs>
#     <g fill="none" fill-rule="evenodd">
#         <mask id="b" fill="#fff">
#             <use href="#facebook"/>
#         </mask>
#         <use fill="#4460A0" href="#facebook"/>
#     </g>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" width="18" height="15" viewBox="0 0 18 15">
#     <defs>
#         <symbol id="twitter">
#             <path d="M21 6.776a7.213 7.213 0 0 1-2.12.596 3.778 3.778 0 0 0 1.623-2.095 7.273 7.273 0 0 1-2.346.918A3.642 3.642 0 0 0 15.462 5c-2.038 0-3.692 1.696-3.692 3.787 0 .296.032.585.095.862-3.069-.158-5.79-1.664-7.612-3.958a3.856 3.856 0 0 0-.5 1.906c0 1.313.652 2.472 1.643 3.152a3.626 3.626 0 0 1-1.673-.473v.047c0 1.835 1.273 3.366 2.963 3.713-.31.089-.636.133-.973.133-.238 0-.47-.023-.695-.067.47 1.504 1.833 2.599 3.45 2.628A7.292 7.292 0 0 1 3 18.3 10.282 10.282 0 0 0 8.66 20c6.794 0 10.508-5.77 10.508-10.774 0-.164-.003-.329-.01-.49A7.58 7.58 0 0 0 21 6.776"/>
#         </symbol>
#     </defs>
#     <g fill="none" fill-rule="evenodd" transform="translate(-3 -5)">
#         <mask id="b" fill="#fff">
#             <use href="#twitter"/>
#         </mask>
#         <use fill="#00AAEC" href="#twitter"/>
#     </g>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24">
#     <defs>
#         <symbol id="sms">
#             <path d="M9.943 17.4L4.8 21v-3.6h-.008A1.8 1.8 0 0 1 3 15.605V4.795A1.79 1.79 0 0 1 4.792 3h14.416A1.8 1.8 0 0 1 21 4.795v10.81a1.79 1.79 0 0 1-1.792 1.795H9.943zm-1.808-4.401c.337 0 .644-.04.832-.09v-1.098c-.09.03-.277.06-.465.06-.327 0-.525-.15-.525-.614V9.079h1.02v-1.07h-1.02V6.683H6.541v1.326h-.663v1.07h.663v2.346c0 1.04.446 1.574 1.594 1.574zm1.208-.099h1.594l1.09-1.515 1.088 1.515h1.643l-1.9-2.495L14.65 8.01h-1.594l-.98 1.386-.98-1.386H9.451l1.792 2.396-1.9 2.495zm7.91.099c.337 0 .644-.04.832-.09v-1.098c-.09.03-.277.06-.465.06-.327 0-.525-.15-.525-.614V9.079h1.02v-1.07h-1.02V6.683h-1.436v1.326h-.663v1.07h.663v2.346c0 1.04.446 1.574 1.594 1.574z"/>
#         </symbol>
#     </defs>
#     <g fill="none" fill-rule="evenodd">
#         <mask id="b" fill="#fff">
#             <use href="#sms"/>
#         </mask>
#         <use fill="#008C33" href="#sms"/>
#     </g>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24">
#     <defs>
#         <symbol id="email">
#             <path d="M21 6.741l-9 4.353L3 6.74v-.865A.88.88 0 0 1 3.893 5h16.214c.493 0 .893.404.893.876v.865zm0 1.741v9.642a.88.88 0 0 1-.893.876H3.893A.892.892 0 0 1 3 18.124V8.482l9 4.353 9-4.353z"/>
#         </symbol>
#     </defs>
#     <g fill="none" fill-rule="evenodd">
#         <mask id="b" fill="#fff">
#             <use href="#email"/>
#         </mask>
#         <use fill="#404040" href="#email"/>
#     </g>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24">
#     <defs>
#         <symbol id="link">
#             <path d="M19.747 10.308l-3.688 3.681a4.279 4.279 0 0 1-6.048 0l-.097-.096c-.367-.395-.277-1.004.103-1.391a1.03 1.03 0 0 1 .734-.298c.256 0 .498.09.685.256.145.16.74.734 1.668.782l.11.007c.658 0 1.322-.277 1.786-.734l3.266-3.273c.478-.47.734-1.093.734-1.758 0-.664-.256-1.287-.727-1.757A2.465 2.465 0 0 0 16.516 5a2.51 2.51 0 0 0-1.765.727l-1.246 1.252c-.408.408-1.017.52-1.591.422-.118-.02-.236-.041-.353-.055-.34-.035-.533-.43-.29-.671l2.421-2.422A4.274 4.274 0 0 1 16.716 3 4.278 4.278 0 0 1 21 7.284c0 1.142-.45 2.214-1.253 3.024zM14.08 10.1c.373.395.277 1.01-.104 1.391-.194.2-.457.305-.727.305a1 1 0 0 1-.692-.256l-.097-.09c-.29-.256-.768-.692-1.695-.692-.983 0-1.647.602-1.765.72L5.727 14.75a2.5 2.5 0 0 0-.734 1.757c0 .665.263 1.295.734 1.758.47.47 1.093.727 1.758.727.657 0 1.294-.263 1.757-.727l1.246-1.245c.408-.409 1.017-.52 1.592-.423.117.021.235.035.36.049.339.034.532.429.29.671l-2.429 2.422a4.222 4.222 0 0 1-3.024 1.253 4.262 4.262 0 0 1-3.024-1.253c-.789-.782-1.246-1.896-1.253-3.045-.014-1.114.43-2.18 1.253-2.996l3.681-3.689a4.25 4.25 0 0 1 3.032-1.252c1.148 0 2.221.443 3.024 1.252l.09.09z"/>
#         </symbol>
#     </defs>
#     <g fill="none" fill-rule="evenodd">
#         <mask id="b" fill="#fff">
#             <use href="#link"/>
#         </mask>
#         <use fill="#000" href="#link"/>
#     </g>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24">
#     <defs>
#         <symbol id="linkedin">
#             <path d="M19.668 3C20.402 3 21 3.581 21 4.298v15.403c0 .717-.598 1.299-1.332 1.299H4.328C3.595 21 3 20.418 3 19.701V4.298C3 3.581 3.595 3 4.328 3h15.34zM7.004 5.478a1.548 1.548 0 1 0-.003 3.095 1.548 1.548 0 0 0 .003-3.095zm-1.337 12.86H8.34v-8.59H5.667v8.59zm4.347-8.59v8.59h2.667v-4.249c0-1.12.212-2.206 1.601-2.206 1.37 0 1.387 1.282 1.387 2.278v4.177h2.67v-4.711c0-2.314-.5-4.092-3.203-4.092-1.299 0-2.17.712-2.526 1.387h-.037V9.748h-2.559z"/>
#         </symbol>
#     </defs>
#     <g fill="none" fill-rule="evenodd">
#         <mask id="b" fill="#fff">
#             <use href="#linkedin"/>
#         </mask>
#         <use fill="#0077B5" href="#linkedin"/>
#     </g>
# </svg>
# </div>
